# %%
import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('covid_vaccine_statewise.csv')

# %%
data.head(200)
# Out:
#      Updated On                        State  Total Individuals Vaccinated  \
# 0    16/01/2021                        India                       48276.0
# 1    17/01/2021                        India                       58604.0
# 2    18/01/2021                        India                       99449.0
# 3    19/01/2021                        India                      195525.0
# 4    20/01/2021                        India                      251280.0
# ..          ...                          ...                           ...
# 195  28/03/2021  Andaman and Nicobar Islands                       16293.0
# 196  29/03/2021  Andaman and Nicobar Islands                       16292.0
# 197  30/03/2021  Andaman and Nicobar Islands                       16701.0
# 198  31/03/2021  Andaman and Nicobar Islands                       16798.0
# 199  01/04/2021  Andaman and Nicobar Islands                       17435.0
#
# ...

# %%
data.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Individuals Vaccinated             38
# Total Sessions Conducted                 38
# Total Sites                              38
# First Dose Administered                  38
# Second Dose Administered                 38
# Male(Individuals Vaccinated)             38
# Female(Individuals Vaccinated)           38
# Transgender(Individuals Vaccinated)      38
# Total Covaxin Administered               38
# Total CoviShield Administered            38
# AEFI                                   2221
# 18-30 years (Age)                      2221
# 30-45 years (Age)                      2221
# 45-60 years (Age)                      2221
# 60+ years (Age)                        2221
# Total Doses Administered                  0
# dtype: int64

# %%
data.shape
# Out:
# (4589, 18)

# %%
data.State.unique()
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df=data.drop([ '18-30 years (Age)', '30-45 years (Age)', '45-60 years (Age)',
       '60+ years (Age)','AEFI'], axis=1)

# %%
df.columns
# Out:
# Index(['Updated On', 'State', 'Total Individuals Vaccinated',
#        'Total Sessions Conducted', 'Total Sites ', 'First Dose Administered',
#        'Second Dose Administered', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Covaxin Administered', 'Total CoviShield Administered',
#        'Total Doses Administered'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Updated On                              0
# State                                   0
# Total Individuals Vaccinated           38
# Total Sessions Conducted               38
# Total Sites                            38
# First Dose Administered                38
# Second Dose Administered               38
# Male(Individuals Vaccinated)           38
# Female(Individuals Vaccinated)         38
# Transgender(Individuals Vaccinated)    38
# Total Covaxin Administered             38
# Total CoviShield Administered          38
# Total Doses Administered                0
# dtype: int64

# %%
df=df.dropna()
df=df.loc[df.State!='India']
df.isnull().sum()
# Out:
# Updated On                             0
# State                                  0
# Total Individuals Vaccinated           0
# Total Sessions Conducted               0
# Total Sites                            0
# First Dose Administered                0
# Second Dose Administered               0
# Male(Individuals Vaccinated)           0
# Female(Individuals Vaccinated)         0
# Transgender(Individuals Vaccinated)    0
# Total Covaxin Administered             0
# Total CoviShield Administered          0
# Total Doses Administered               0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['Total Individuals Vaccinated'],df.State)

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['Total Sessions Conducted'],df.State)

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['Total Covaxin Administered'],df.State)

# %%
df.columns
# Out:
# Index(['Updated On', 'State', 'Total Individuals Vaccinated',
#        'Total Sessions Conducted', 'Total Sites ', 'First Dose Administered',
#        'Second Dose Administered', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Covaxin Administered', 'Total CoviShield Administered',
#        'Total Doses Administered'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['Total CoviShield Administered'],df.State)

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['Total Doses Administered'],df.State)

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
sns.barplot(df['First Dose Administered'],df.State)
plt.subplot(1,2,2)
sns.barplot(df['Second Dose Administered'],df.State)

# %%
df.columns
# Out:
# Index(['Updated On', 'State', 'Total Individuals Vaccinated',
#        'Total Sessions Conducted', 'Total Sites ', 'First Dose Administered',
#        'Second Dose Administered', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Covaxin Administered', 'Total CoviShield Administered',
#        'Total Doses Administered'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.barplot(df['Female(Individuals Vaccinated)'],df.State)
plt.subplot(1,2,2)
sns.barplot(df['Male(Individuals Vaccinated)'],df.State)

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                                      Total Individuals Vaccinated  \
# Total Individuals Vaccinated                             1.000000
# Total Sessions Conducted                                 0.833143
# Total Sites                                              0.639419
# First Dose Administered                                  0.999815
# Second Dose Administered                                 0.938328
# Male(Individuals Vaccinated)                             0.998017
# Female(Individuals Vaccinated)                           0.997551
# Transgender(Individuals Vaccinated)                      0.981447
# Total Covaxin Administered                               0.901279
# Total CoviShield Administered                            0.997443
# Total Doses Administered                                 0.997835
#
#                                      Total Sessions Conducted  Total Sites   \
# Total Individuals Vaccinated                         0.833143      0.639419
# ...
